# %% [markdown]
# # Load Data

# %%
import bz2
import json

path_to_file = 'quotes-2020.json.bz2' 
path_to_out = 'quotes-2020-clean.json.bz2'

with bz2.open(path_to_file, 'rb') as s_file:
    with bz2.open(path_to_out, 'wb') as d_file:
        count = 0
        for instance in s_file:
            instance = json.loads(instance) # loading a sample
            count+= 1
            print(instance.keys())
            if(count == 5):
                break

            '''
            urls = instance['urls'] # extracting list of links
            domains = []
            for url in urls:
                tld = get_domain(url)
                domains.append(tld)
            instance['domains'] = domains # updating the sample with domain name
            d_file.write((json.dumps(instance)+'\n').encode('utf-8')) # writing in the new file
            '''
# Out:
# dict_keys(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences', 'probas', 'urls', 'phase'])
# dict_keys(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences', 'probas', 'urls', 'phase'])
# dict_keys(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences', 'probas', 'urls', 'phase'])
# dict_keys(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences', 'probas', 'urls', 'phase'])
# dict_keys(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences', 'probas', 'urls', 'phase'])

# %%
import pandas as pd

pd.read_parquet("speaker_attributes.parquet/part-00000-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet")
# Out:
#                                                   aliases  \
# 0       [Washington, President Washington, G. Washingt...
# 1       [Douglas Noel Adams, Douglas Noël Adams, Dougl...
# 2           [Paul Marie Ghislain Otlet, Paul Marie Otlet]
# 3       [George Walker Bush, Bush Jr., Dubya, GWB, Bus...
# 4       [Velázquez, Diego Rodríguez de Silva y Velázqu...
# ...                                                   ...
# 472363                                               None
# 472364                                               None
# 472365                                               None
# 472366                           [Lehuan, Huang, Zhuquan]
# 472367  [Niansihuafengguan, Pingshu, Jianshi, Jianfeng...
#
#                   date_of_birth     nationality      gender   lastrevid  \
# 0       [+1732-02-22T00:00:00Z]  [Q161885, Q30]  [Q6581097]  1395141751
# 1       [+1952-03-11T00:00:00Z]          [Q145]  [Q6581097]  1395737157
# 2       [+1868-08-23T00:00:00Z]           [Q31]  [Q6581097]  1380367296
# 3       [+1946-07-06T00:00:00Z]           [Q30]  [Q6581097]  1395142029
# 4       [+1599-06-06T00:00:00Z]           [Q29]  [Q6581097]  1391704596
# ...                         ...             ...         ...         ...
# 472363                     None         [Q7313]  [Q6581097]  1368598379
# 472364                     None         [Q9903]  [Q6581097]  1008697903
# 472365                     None         [Q9683]  [Q6581097]   985208307
# 472366                     None         [Q7313]  [Q6581097]   984992515
# 472367                     None          [Q865]  [Q6581097]  1012782970
#
#        ethnic_group US_congress_bio_ID  \
# 0              None            W000178
# 1        [Q7994501]               None
# 2              None               None
# 3              None               None
# 4              None               None
# ...             ...                ...
# 472363         None               None
# 472364         None               None
# 472365         None               None
# 472366         None               None
# 472367         None               None
#
#                                                occupation      party  \
# 0       [Q82955, Q189290, Q131512, Q1734662, Q294126, ...  [Q327591]
# 1       [Q214917, Q28389, Q6625963, Q4853732, Q1884422...       None
# 2       [Q36180, Q40348, Q182436, Q1265807, Q205375, Q...       None
# 3       [Q82955, Q15982858, Q18814623, Q1028181, Q1408...   [Q29468]
# 4                                              [Q1028181]       None
# ...                                                   ...        ...
# 472363                                               None       None
# 472364                                               None       None
# 472365                                               None       None
# 472366                                               None       None
# 472367                                               None       None
#
#        academic_degree         id              label  \
# 0                 None        Q23  George Washington
# 1                 None        Q42      Douglas Adams
# 2                 None      Q1868         Paul Otlet
# 3                 None       Q207     George W. Bush
# 4                 None       Q297    Diego Velázquez
# ...                ...        ...                ...
# 472363            None  Q45441479          Chen Wang
# 472364            None  Q45441495          Zhou Gong
# 472365            None  Q45441510      Wang Changxin
# 472366            None  Q45441517          Shi Falin
# 472367            None  Q45441518     Chen Zhaochang
#
#                                      candidacy  type  \
# 0                           [Q698073, Q697949]  item
# 1                                         None  item
# 2                                         None  item
# 3       [Q327959, Q464075, Q3586276, Q4450587]  item
# 4                                         None  item
# ...                                        ...   ...
# 472363                                    None  item
# 472364                                    None  item
# 472365                                    None  item
# 472366                                    None  item
# 472367                                    None  item
#
#                           religion
# 0                        [Q682443]
# 1                             None
# 2                             None
# 3       [Q329646, Q682443, Q33203]
# 4                             None
# ...                            ...
# 472363                        None
# 472364                        None
# 472365                        None
# 472366                        None
# 472367                        None
#
# [472368 rows x 15 columns]

# %%
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 73c68257545b5f8530b7044f56647bd2db92e2ba
# python           : 3.8.12.final.0
# python-bits      : 64
# OS               : Darwin
# OS-release       : 20.6.0
# Version          : Darwin Kernel Version 20.6.0: Mon Aug 30 06:12:21 PDT 2021; root:xnu-7195.141.6~3/RELEASE_X86_64
# machine          : x86_64
# processor        : i386
# byteorder        : little
# LC_ALL           : en_US.UTF-8
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.3.3
# numpy            : 1.21.2
# pytz             : 2021.3
# dateutil         : 2.8.2
# pip              : 21.2.4
# setuptools       : 58.0.4
# Cython           : None
# pytest           : None
# hypothesis       : None
# sphinx           : None
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : None
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : 3.0.1
# IPython          : 7.27.0
# pandas_datareader: None
# bs4              : None
# bottleneck       : 1.3.2
# fsspec           : 2021.10.1
# fastparquet      : 0.7.1
# gcsfs            : None
# matplotlib       : 3.4.3
# numexpr          : 2.7.3
# odfpy            : None
# openpyxl         : None
# pandas_gbq       : None
# pyarrow          : 4.0.0
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.7.1
# sqlalchemy       : None
# tables           : None
# tabulate         : None
# xarray           : None
# xlrd             : None
# xlwt             : None
# numba            : None
